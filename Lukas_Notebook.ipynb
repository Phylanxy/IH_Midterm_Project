# %% [markdown]
# ## General Exploration of the dataset

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("nys_homes.csv")
df.head()
# Out:
#           Reporting Period Home Performance Project ID  \
# 0  2020-02-12T00:00:00.000                      483911
# 1  2020-02-12T00:00:00.000                      486389
# 2  2020-02-12T00:00:00.000                      483374
# 3  2020-02-12T00:00:00.000                      475733
# 4  2020-02-12T00:00:00.000                      483731
#
#   Home Performance Site ID Project County Project City  Project Zip  \
# 0                   357221         Oneida    Barneveld        13304
# 1                   343438          Wayne      Palmyra        14522
# 2                   356880           Erie      Buffalo        14215
# 3                   350454         Oneida         Rome        13440
# 4                   356491     Livingston         Lima        14485
#
#                       Gas Utility               Electric Utility  \
# 0                             NaN                  National Grid
# 1                             NaN  New York State Electric & Gas
# 2  National Fuel Gas Distribution                  National Grid
# 3                             NaN                  National Grid
# 4                             NaN                  National Grid
#
#    Project Completion Date Customer Type  \
# 0  2021-01-16T00:00:00.000      Assisted
# 1  2021-01-06T00:00:00.000      Assisted
# 2  2020-12-15T00:00:00.000      Assisted
# 3  2020-12-09T00:00:00.000      Assisted
# 4  2020-12-08T00:00:00.000      Assisted
#
#   Low-Rise or Home Performance Indicator  Total Project Cost  \
# 0                       Home Performance                5900
# 1                       Home Performance                9980
# 2                       Home Performance                5000
# 3                       Home Performance                4200
# 4                       Home Performance                5890
#
#    Total Incentives Type of Program Financing  \
# 0              2950                       NaN
# 1              3250                       NaN
# 2              2500                       NaN
# 3              2088                       NaN
# 4              2945                       NaN
#
#    Amount Financed Through Program Pre-Retrofit Home Heating Fuel Type  \
# 0                                0                                 NaN
# 1                                0                             Propane
# 2                                0                         Natural Gas
# 3                                0                                 NaN
# 4                                0                             Propane
#
#    Year Home Built  Size of Home  Volume of Home  Number of Units  \
# 0           1947.0        2398.0         19184.0              1.0
# 1           1966.0        1092.0          8517.0              1.0
# 2           1928.0        1616.0         20516.0              1.0
# 3           1971.0         980.0          7840.0              1.0
# 4           1984.0         940.0          7520.0              1.0
#
#      Measure Type  Estimated Annual kWh Savings  \
# 0  Building Shell                             0
# 1  Building Shell                           309
# 2  Building Shell                             0
# 3  Building Shell                             0
# 4  Building Shell                             0
#
#    Estimated Annual MMBtu Savings  First Year Energy Savings $ Estimate  \
# 0                              27                                   474
# 1                               3                                   111
# 2                               8                                    61
# 3                              28                                   681
# 4                               6                                   146
#
#   Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# 4                                                  Y
#
#                             New Georeferenced Column  New York Zip Codes 2  \
# 0  {'type': 'Point', 'coordinates': [-75.16936, 4...                 764.0
# 1  {'type': 'Point', 'coordinates': [-77.218837, ...                 364.0
# 2  {'type': 'Point', 'coordinates': [-78.808435, ...                  71.0
# 3  {'type': 'Point', 'coordinates': [-75.454665, ...                1366.0
# 4  {'type': 'Point', 'coordinates': [-77.603561, ...                 312.0
#
#    Counties 2  NYS Municipal Boundaries 2
# 0       625.0                         985
# 1       631.0                         631
# 2      2041.0                         300
# 3       625.0                         989
# 4      2091.0                         742

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55830 entries, 0 to 55829
# Data columns (total 29 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Reporting Period                                                      55830 non-null  object
#  1   Home Performance Project ID                                           55830 non-null  object
#  2   Home Performance Site ID                                              55830 non-null  object
#  3   Project County                                                        55830 non-null  object
#  4   Project City                                                          55830 non-null  object
#  5   Project Zip                                                           55830 non-null  int64
#  6   Gas Utility                                                           39852 non-null  object
#  7   Electric Utility                                                      55830 non-null  object
#  8   Project Completion Date                                               55830 non-null  object
#  9   Customer Type                                                         55830 non-null  object
#  10  Low-Rise or Home Performance Indicator                                55830 non-null  object
#  11  Total Project Cost                                                    55830 non-null  int64
#  12  Total Incentives                                                      55830 non-null  int64
#  13  Type of Program Financing                                             18465 non-null  object
#  14  Amount Financed Through Program                                       55830 non-null  int64
#  15  Pre-Retrofit Home Heating Fuel Type                                   55437 non-null  object
#  16  Year Home Built                                                       38956 non-null  float64
#  17  Size of Home                                                          47629 non-null  float64
#  18  Volume of Home                                                        47629 non-null  float64
#  19  Number of Units                                                       38971 non-null  float64
#  20  Measure Type                                                          55830 non-null  object
#  21  Estimated Annual kWh Savings                                          55830 non-null  int64
#  22  Estimated Annual MMBtu Savings                                        55830 non-null  int64
#  23  First Year Energy Savings $ Estimate                                  55830 non-null  int64
#  24  Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)  55830 non-null  object
#  25  New Georeferenced Column                                              55830 non-null  object
#  26  New York Zip Codes 2                                                  55729 non-null  float64
#  27  Counties 2                                                            55826 non-null  float64
#  28  NYS Municipal Boundaries 2                                            55830 non-null  int64
# dtypes: float64(6), int64(8), object(15)
# memory usage: 12.4+ MB

# %%
df.describe()
# Out:
#         Project Zip  Total Project Cost  Total Incentives  \
# count  55830.000000        55830.000000      55830.000000
# mean   13384.720186         8572.804263       1687.311195
# std     1322.839629         5582.971049       1705.700197
# min    10001.000000            0.000000          0.000000
# 25%    12303.000000         4700.000000        301.000000
# 50%    13901.000000         7286.000000       1004.000000
# 75%    14534.000000        10757.000000       2899.000000
# max    14905.000000        85290.000000      10000.000000
#
#        Amount Financed Through Program  Year Home Built  Size of Home  \
# count                     55830.000000     38956.000000  47629.000000
# mean                       2804.978864      1947.020741   1911.659094
# std                        5084.037361        37.416552    682.743735
# min                           0.000000      1800.000000    800.000000
# 25%                           0.000000      1925.000000   1396.000000
# 50%                           0.000000      1954.000000   1800.000000
# 75%                        4306.500000      1972.000000   2309.000000
# max                       25000.000000      2019.000000   4000.000000
#
#        Volume of Home  Number of Units  Estimated Annual kWh Savings  \
# count    47629.000000     38971.000000                  55830.000000
# mean     16268.797938         1.035514                    363.592853
# std       6380.773571         0.228171                   1691.176724
# min       1111.000000         1.000000                 -27585.000000
# 25%      11544.000000         1.000000                      0.000000
# 50%      15112.000000         1.000000                      4.000000
# 75%      19681.000000         1.000000                    313.000000
# max      70376.000000         4.000000                  63480.000000
#
#        Estimated Annual MMBtu Savings  First Year Energy Savings $ Estimate  \
# count                    55830.000000                          55830.000000
# mean                        28.621333                            596.212735
# std                         26.469325                            683.551809
# min                       -214.000000                              0.000000
# 25%                         11.000000                            160.000000
# 50%                         22.000000                            352.000000
# 75%                         39.000000                            763.000000
# max                        445.000000                           5981.000000
#
#        New York Zip Codes 2    Counties 2  NYS Municipal Boundaries 2
# count          55729.000000  55826.000000                55830.000000
# mean             908.404547   1943.778311                  600.700143
# std              577.397190    474.661250                  284.112762
# min                2.000000    618.000000                    1.000000
# 25%              366.000000   2041.000000                  437.000000
# 50%              928.000000   2093.000000                  549.000000
# 75%             1459.000000   2135.000000                  814.000000
# max             1792.000000   2225.000000                 1023.000000

# %% [markdown]
# ## Unifying column names

# %%
#Function to rename columns
def rename_df(df, rename_dict):
    df.rename(columns = rename_dict, inplace=True)
    return df

# %%
#Function to rename columns
new_clm_names = {"Reporting Period": "Reporting Period",
              "Home Performance Project ID": "Home Performance Project ID",
              "Home Performance Site ID": "Home Performance Site ID",
              "Project County": "Project County",
              "Project City": "Project City",
              "Project Zip": "Project Zip",
              "Gas Utility": "Gas Utility Provider",
              "Electric Utility": "Electric Utility Provider",
              "Project Completion Date": "Project Completion Date",
              "Customer Type": "Customer Type",
              "Low-Rise or Home Performance Indicator": "Job Type",
              "Total Project Cost": "Total Project Cost",
              "Total Incentives": "Total Incentives",
              "Type of Program Financing": "Type of Program Financing",
              "Amount Financed Through Program": "Amount Financed Through Program",
              "Pre-Retrofit Home Heating Fuel Type": "Pre-Retrofit Home Heating Fuel Type",
              "Year Home Built": "Year Home Built",
              "Size of Home": "Size of Home",
              "Volume of Home": "Volume of Home",
              "Number of Units": "Number of Units",
              "Measure Type": "Measure Type",
              "Estimated Annual kWh Savings": "Estimated Annual kWh Savings",
              "Estimated Annual MMBtu Savings": "Estimated Annual MMBtu Savings",
              "First Year Energy Savings $ Estimate": "First Year Energy Savings $ Estimate",
              "Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)": "Homeowner Received Free/Reduced Cost Audit?",
              "New Georeferenced Column": "Location",
              "New York Zip Codes 2": "New York Zip Codes",
              "Counties 2": "Counties 2",
              "NYS Municipal Boundaries 2": "NYS Municipal Boundaries 2"}

rename_df(df, new_clm_names)
# Out:
#               Reporting Period Home Performance Project ID  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       Home Performance Site ID Project County Project City  Project Zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  Gas Utility Provider      Electric Utility Provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        Project Completion Date Customer Type          Job Type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        Total Project Cost  Total Incentives Type of Program Financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        Amount Financed Through Program Pre-Retrofit Home Heating Fuel Type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural gas
# 55829                                0                         Natural gas
#
#        Year Home Built  Size of Home  Volume of Home  Number of Units  \
# 0               1947.0        2398.0         19184.0              1.0
# 1               1966.0        1092.0          8517.0              1.0
# 2               1928.0        1616.0         20516.0              1.0
# 3               1971.0         980.0          7840.0              1.0
# 4               1984.0         940.0          7520.0              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0        1788.0         14304.0              1.0
# 55826           1949.0        2963.0         23704.0              1.0
# 55827           1968.0        1080.0          8640.0              1.0
# 55828           1965.0        3272.0         25385.0              1.0
# 55829           1959.0        2340.0         18720.0              1.0
#
#          Measure Type  Estimated Annual kWh Savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        Estimated Annual MMBtu Savings  First Year Energy Savings $ Estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#       Homeowner Received Free/Reduced Cost Audit?  \
# 0                                               Y
# 1                                               Y
# 2                                               Y
# 3                                               Y
# 4                                               Y
# ...                                           ...
# 55825                                           N
# 55826                                           N
# 55827                                           N
# 55828                                           N
# 55829                                           N
#
#                                                 Location  New York Zip Codes  \
# 0      {'type': 'Point', 'coordinates': [-75.16936, 4...               764.0
# 1      {'type': 'Point', 'coordinates': [-77.218837, ...               364.0
# 2      {'type': 'Point', 'coordinates': [-78.808435, ...                71.0
# 3      {'type': 'Point', 'coordinates': [-75.454665, ...              1366.0
# 4      {'type': 'Point', 'coordinates': [-77.603561, ...               312.0
# ...                                                  ...                 ...
# 55825  {'type': 'Point', 'coordinates': [-78.702553, ...               506.0
# 55826  {'type': 'Point', 'coordinates': [-73.932117, ...                72.0
# 55827  {'type': 'Point', 'coordinates': [-76.359264, ...               622.0
# 55828  {'type': 'Point', 'coordinates': [-77.597999, ...              1676.0
# 55829  {'type': 'Point', 'coordinates': [-77.729647, ...              1683.0
#
#        Counties 2  NYS Municipal Boundaries 2
# 0           625.0                         985
# 1           631.0                         631
# 2          2041.0                         300
# 3           625.0                         989
# 4          2091.0                         742
# ...           ...                         ...
# 55825      2041.0                         298
# 55826      2030.0                         832
# 55827      2181.0                         712
# 55828      2093.0                         545
# 55829      2093.0                         549
#
# [55830 rows x 29 columns]

# %%
#Function to transform each column into small capital letters
def column_into_small_letters(df):
    for column in df.columns:
        df.rename(columns = {column:column.replace(" ", "_").lower()}, inplace = True)
    return df

# %%
column_into_small_letters(df)
# Out:
#               reporting_period home_performance_project_id  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       home_performance_site_id project_county project_city  project_zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  gas_utility_provider      electric_utility_provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        project_completion_date customer_type          job_type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        total_project_cost  total_incentives type_of_program_financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        amount_financed_through_program pre-retrofit_home_heating_fuel_type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural gas
# 55829                                0                         Natural gas
#
#        year_home_built  size_of_home  volume_of_home  number_of_units  \
# 0               1947.0        2398.0         19184.0              1.0
# 1               1966.0        1092.0          8517.0              1.0
# 2               1928.0        1616.0         20516.0              1.0
# 3               1971.0         980.0          7840.0              1.0
# 4               1984.0         940.0          7520.0              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0        1788.0         14304.0              1.0
# 55826           1949.0        2963.0         23704.0              1.0
# 55827           1968.0        1080.0          8640.0              1.0
# 55828           1965.0        3272.0         25385.0              1.0
# 55829           1959.0        2340.0         18720.0              1.0
#
#          measure_type  estimated_annual_kwh_savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        estimated_annual_mmbtu_savings  first_year_energy_savings_$_estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#       homeowner_received_free/reduced_cost_audit?  \
# 0                                               Y
# 1                                               Y
# 2                                               Y
# 3                                               Y
# 4                                               Y
# ...                                           ...
# 55825                                           N
# 55826                                           N
# 55827                                           N
# 55828                                           N
# 55829                                           N
#
#                                                 location  new_york_zip_codes  \
# 0      {'type': 'Point', 'coordinates': [-75.16936, 4...               764.0
# 1      {'type': 'Point', 'coordinates': [-77.218837, ...               364.0
# 2      {'type': 'Point', 'coordinates': [-78.808435, ...                71.0
# 3      {'type': 'Point', 'coordinates': [-75.454665, ...              1366.0
# 4      {'type': 'Point', 'coordinates': [-77.603561, ...               312.0
# ...                                                  ...                 ...
# 55825  {'type': 'Point', 'coordinates': [-78.702553, ...               506.0
# 55826  {'type': 'Point', 'coordinates': [-73.932117, ...                72.0
# 55827  {'type': 'Point', 'coordinates': [-76.359264, ...               622.0
# 55828  {'type': 'Point', 'coordinates': [-77.597999, ...              1676.0
# 55829  {'type': 'Point', 'coordinates': [-77.729647, ...              1683.0
#
#        counties_2  nys_municipal_boundaries_2
# 0           625.0                         985
# 1           631.0                         631
# 2          2041.0                         300
# 3           625.0                         989
# 4          2091.0                         742
# ...           ...                         ...
# 55825      2041.0                         298
# 55826      2030.0                         832
# 55827      2181.0                         712
# 55828      2093.0                         545
# 55829      2093.0                         549
#
# [55830 rows x 29 columns]

# %% [markdown]
# ## Column 15: Pre-Retrofit Home Heating Fuel Type

# %%
df["pre-retrofit_home_heating_fuel_type"].value_counts()
# Out:
# Natural Gas        26494
# Oil                12547
# Natural gas        11807
# Propane             2933
# Electricity          893
# Wood                 421
# Wood Pellets         165
# Kerosene             117
# Coal                  48
# Bituminous Coal        5
# Anthracite Coal        5
# Electric               2
# Name: pre-retrofit_home_heating_fuel_type, dtype: int64

# %%
#Function to unify entries in column according to given translator dictionary
def unify_column_entries(df, translator, column):
    df.replace({column: translator}, inplace = True)
    
    return df

# %%
#Application of unity_column_entries function
translator = {"Natural Gas" : "Natural Gas",
             "Oil": "Oil",
             "Natural gas": "Natural Gas",
             "Propane": "Propane",
             "Electricity": "Electricity",
             "Wood": "Wood",
             "Kerosene": "Kerosene",
             "Coal": "Coal",
             "Bituminous Coal": "Bituminous Coal",
             "Anthracite Coal": "Anthracite Coal",
             "Electric": "Electricity"}

unify_column_entries(df, translator, "pre-retrofit_home_heating_fuel_type")
# Out:
#               reporting_period home_performance_project_id  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       home_performance_site_id project_county project_city  project_zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  gas_utility_provider      electric_utility_provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        project_completion_date customer_type          job_type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        total_project_cost  total_incentives type_of_program_financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        amount_financed_through_program pre-retrofit_home_heating_fuel_type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural Gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural Gas
# 55829                                0                         Natural Gas
#
#        year_home_built  size_of_home  volume_of_home  number_of_units  \
# 0               1947.0        2398.0         19184.0              1.0
# 1               1966.0        1092.0          8517.0              1.0
# 2               1928.0        1616.0         20516.0              1.0
# 3               1971.0         980.0          7840.0              1.0
# 4               1984.0         940.0          7520.0              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0        1788.0         14304.0              1.0
# 55826           1949.0        2963.0         23704.0              1.0
# 55827           1968.0        1080.0          8640.0              1.0
# 55828           1965.0        3272.0         25385.0              1.0
# 55829           1959.0        2340.0         18720.0              1.0
#
#          measure_type  estimated_annual_kwh_savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        estimated_annual_mmbtu_savings  first_year_energy_savings_$_estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#       homeowner_received_free/reduced_cost_audit?  \
# 0                                               Y
# 1                                               Y
# 2                                               Y
# 3                                               Y
# 4                                               Y
# ...                                           ...
# 55825                                           N
# 55826                                           N
# 55827                                           N
# 55828                                           N
# 55829                                           N
#
#                                                 location  new_york_zip_codes  \
# 0      {'type': 'Point', 'coordinates': [-75.16936, 4...               764.0
# 1      {'type': 'Point', 'coordinates': [-77.218837, ...               364.0
# 2      {'type': 'Point', 'coordinates': [-78.808435, ...                71.0
# 3      {'type': 'Point', 'coordinates': [-75.454665, ...              1366.0
# 4      {'type': 'Point', 'coordinates': [-77.603561, ...               312.0
# ...                                                  ...                 ...
# 55825  {'type': 'Point', 'coordinates': [-78.702553, ...               506.0
# 55826  {'type': 'Point', 'coordinates': [-73.932117, ...                72.0
# 55827  {'type': 'Point', 'coordinates': [-76.359264, ...               622.0
# 55828  {'type': 'Point', 'coordinates': [-77.597999, ...              1676.0
# 55829  {'type': 'Point', 'coordinates': [-77.729647, ...              1683.0
#
#        counties_2  nys_municipal_boundaries_2
# 0           625.0                         985
# 1           631.0                         631
# 2          2041.0                         300
# 3           625.0                         989
# 4          2091.0                         742
# ...           ...                         ...
# 55825      2041.0                         298
# 55826      2030.0                         832
# 55827      2181.0                         712
# 55828      2093.0                         545
# 55829      2093.0                         549
#
# [55830 rows x 29 columns]

# %%
df["pre-retrofit_home_heating_fuel_type"].value_counts()
# Out:
# Natural Gas        38301
# Oil                12547
# Propane             2933
# Electricity          895
# Wood                 421
# Wood Pellets         165
# Kerosene             117
# Coal                  48
# Bituminous Coal        5
# Anthracite Coal        5
# Name: pre-retrofit_home_heating_fuel_type, dtype: int64

# %% [markdown]
# ## Column 16: Year Home Built

# %%
df[df["year_home_built"].isna()].shape
# Out:
# (16874, 29)

# %%
import seaborn as sns
sns.histplot(df["year_home_built"])
# Out:
# <AxesSubplot:xlabel='year_home_built', ylabel='Count'>

# %% [markdown]
# ## Column 17: Size of Home

# %%
df[df["size_of_home"].isna()].shape
# Out:
# (8201, 29)

# %%
df["size_of_home"].describe()
# Out:
# count    47629.000000
# mean      1911.659094
# std        682.743735
# min        800.000000
# 25%       1396.000000
# 50%       1800.000000
# 75%       2309.000000
# max       4000.000000
# Name: size_of_home, dtype: float64

# %%
df["size_of_home"] = df["size_of_home"]*0.0929

# %%
df["size_of_home"].value_counts()
# Out:
# 111.4800    459
# 167.2200    401
# 133.7760    341
# 185.8000    335
# 148.6400    332
#            ...
# 336.1122      1
# 87.9763       1
# 311.6795      1
# 371.0426      1
# 242.5619      1
# Name: size_of_home, Length: 2998, dtype: int64

# %% [markdown]
# ## Column 18: Volume of Home

# %%
df[df["volume_of_home"].isna()].shape
# Out:
# (8201, 29)

# %%
df["volume_of_home"].describe()
# Out:
# count    47629.000000
# mean     16268.797938
# std       6380.773571
# min       1111.000000
# 25%      11544.000000
# 50%      15112.000000
# 75%      19681.000000
# max      70376.000000
# Name: volume_of_home, dtype: float64

# %%
df["volume_of_home"] = df["volume_of_home"]*0.02832

# %%
df["volume_of_home"].value_counts()
# Out:
# 271.87200     309
# 407.80800     252
# 326.24640     219
# 217.49760     185
# 453.12000     180
#              ...
# 365.24304       1
# 1026.57168      1
# 228.96720       1
# 352.95216       1
# 718.90320       1
# Name: volume_of_home, Length: 11057, dtype: int64

# %% [markdown]
# ## Column 19: Number of Units

# %%
df[df["number_of_units"].isna()].shape
# Out:
# (16859, 29)

# %%
df[df["number_of_units"] == 0].shape
# Out:
# (0, 29)

# %%
df["number_of_units"].describe()
# Out:
# count    38971.000000
# mean         1.035514
# std          0.228171
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: number_of_units, dtype: float64

# %%
df["number_of_units"].value_counts()
# Out:
# 1.0    37854
# 2.0      930
# 3.0      107
# 4.0       80
# Name: number_of_units, dtype: int64

# %% [markdown]
# ## Column 20: Measure Type

# %%
df[df["measure_type"].isna()].shape
# Out:
# (0, 29)

# %%
df["measure_type"].describe()
# Out:
# count              55830
# unique                 3
# top       Building Shell
# freq               55299
# Name: measure_type, dtype: object

# %%
df["measure_type"].value_counts()
# Out:
# Building Shell         55299
# Heating and Cooling      525
# Water Heater               6
# Name: measure_type, dtype: int64

# %% [markdown]
# ## Column 21: Estimated Annual kWh Savings

# %%
df[df["estimated_annual_kwh_savings"].isna()].shape
# Out:
# (0, 29)

# %%
df[df["estimated_annual_kwh_savings"] == 0].shape
# Out:
# (23244, 29)

# %%
df["estimated_annual_kwh_savings"].describe()
# Out:
# count    55830.000000
# mean       363.592853
# std       1691.176724
# min     -27585.000000
# 25%          0.000000
# 50%          4.000000
# 75%        313.000000
# max      63480.000000
# Name: estimated_annual_kwh_savings, dtype: float64

# %%
sns.histplot(df["estimated_annual_kwh_savings"])
# Out:
# <AxesSubplot:xlabel='estimated_annual_kwh_savings', ylabel='Count'>

# %% [markdown]
# ## Column 22: Estimated Annual MMBtu Savings

# %%
df[df["estimated_annual_mmbtu_savings"].isna()].shape
# Out:
# (0, 29)

# %%
df[df["estimated_annual_mmbtu_savings"] == 0].shape
# Out:
# (2913, 29)

# %%
df["estimated_annual_mmbtu_savings"].describe()
# Out:
# count    55830.000000
# mean        28.621333
# std         26.469325
# min       -214.000000
# 25%         11.000000
# 50%         22.000000
# 75%         39.000000
# max        445.000000
# Name: estimated_annual_mmbtu_savings, dtype: float64

# %%
sns.histplot(df["estimated_annual_mmbtu_savings"])
# Out:
# <AxesSubplot:xlabel='estimated_annual_mmbtu_savings', ylabel='Count'>

# %% [markdown]
# ## Column 23: First Year Energy Savings $ Estimate

# %%
df[df["first_year_energy_savings_$_estimate"].isna()].shape
# Out:
# (0, 29)

# %%
df[df["first_year_energy_savings_$_estimate"] == 0].shape
# Out:
# (106, 29)

# %%
df["first_year_energy_savings_$_estimate"].describe()
# Out:
# count    55830.000000
# mean       596.212735
# std        683.551809
# min          0.000000
# 25%        160.000000
# 50%        352.000000
# 75%        763.000000
# max       5981.000000
# Name: first_year_energy_savings_$_estimate, dtype: float64

# %%
sns.histplot(df["first_year_energy_savings_$_estimate"])
# Out:
# <AxesSubplot:xlabel='first_year_energy_savings_$_estimate', ylabel='Count'>

# %%
df
# Out:
#               reporting_period home_performance_project_id  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       home_performance_site_id project_county project_city  project_zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  gas_utility_provider      electric_utility_provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        project_completion_date customer_type          job_type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        total_project_cost  total_incentives type_of_program_financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        amount_financed_through_program pre-retrofit_home_heating_fuel_type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural Gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural Gas
# 55829                                0                         Natural Gas
#
#        year_home_built  size_of_home  volume_of_home  number_of_units  \
# 0               1947.0      222.7742       543.29088              1.0
# 1               1966.0      101.4468       241.20144              1.0
# 2               1928.0      150.1264       581.01312              1.0
# 3               1971.0       91.0420       222.02880              1.0
# 4               1984.0       87.3260       212.96640              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0      166.1052       405.08928              1.0
# 55826           1949.0      275.2627       671.29728              1.0
# 55827           1968.0      100.3320       244.68480              1.0
# 55828           1965.0      303.9688       718.90320              1.0
# 55829           1959.0      217.3860       530.15040              1.0
#
#          measure_type  estimated_annual_kwh_savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        estimated_annual_mmbtu_savings  first_year_energy_savings_$_estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#       homeowner_received_free/reduced_cost_audit?  \
# 0                                               Y
# 1                                               Y
# 2                                               Y
# 3                                               Y
# 4                                               Y
# ...                                           ...
# 55825                                           N
# 55826                                           N
# 55827                                           N
# 55828                                           N
# 55829                                           N
#
#                                                 location  new_york_zip_codes  \
# 0      {'type': 'Point', 'coordinates': [-75.16936, 4...               764.0
# 1      {'type': 'Point', 'coordinates': [-77.218837, ...               364.0
# 2      {'type': 'Point', 'coordinates': [-78.808435, ...                71.0
# 3      {'type': 'Point', 'coordinates': [-75.454665, ...              1366.0
# 4      {'type': 'Point', 'coordinates': [-77.603561, ...               312.0
# ...                                                  ...                 ...
# 55825  {'type': 'Point', 'coordinates': [-78.702553, ...               506.0
# 55826  {'type': 'Point', 'coordinates': [-73.932117, ...                72.0
# 55827  {'type': 'Point', 'coordinates': [-76.359264, ...               622.0
# 55828  {'type': 'Point', 'coordinates': [-77.597999, ...              1676.0
# 55829  {'type': 'Point', 'coordinates': [-77.729647, ...              1683.0
#
#        counties_2  nys_municipal_boundaries_2
# 0           625.0                         985
# 1           631.0                         631
# 2          2041.0                         300
# 3           625.0                         989
# 4          2091.0                         742
# ...           ...                         ...
# 55825      2041.0                         298
# 55826      2030.0                         832
# 55827      2181.0                         712
# 55828      2093.0                         545
# 55829      2093.0                         549
#
# [55830 rows x 29 columns]

# %% [markdown]
# ## Column 24: Homeowner Received Green Jobs-Green NY Free/Reduced Cost Audit (Y/N)

# %%
df[df["homeowner_received_free/reduced_cost_audit?"].isna()].shape
# Out:
# (0, 29)

# %%
df[df["homeowner_received_free/reduced_cost_audit?"] == 0].shape
# Out:
# (0, 29)

# %%
df["homeowner_received_free/reduced_cost_audit?"].value_counts()
# Out:
# Y    47464
# N     8366
# Name: homeowner_received_free/reduced_cost_audit?, dtype: int64

# %%
clm24_translator = {"Y": True, "N": False}

# %%
unify_column_entries(df, clm24_translator, "homeowner_received_free/reduced_cost_audit?")
# Out:
#               reporting_period home_performance_project_id  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       home_performance_site_id project_county project_city  project_zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  gas_utility_provider      electric_utility_provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        project_completion_date customer_type          job_type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        total_project_cost  total_incentives type_of_program_financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        amount_financed_through_program pre-retrofit_home_heating_fuel_type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural Gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural Gas
# 55829                                0                         Natural Gas
#
#        year_home_built  size_of_home  volume_of_home  number_of_units  \
# 0               1947.0      222.7742       543.29088              1.0
# 1               1966.0      101.4468       241.20144              1.0
# 2               1928.0      150.1264       581.01312              1.0
# 3               1971.0       91.0420       222.02880              1.0
# 4               1984.0       87.3260       212.96640              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0      166.1052       405.08928              1.0
# 55826           1949.0      275.2627       671.29728              1.0
# 55827           1968.0      100.3320       244.68480              1.0
# 55828           1965.0      303.9688       718.90320              1.0
# 55829           1959.0      217.3860       530.15040              1.0
#
#          measure_type  estimated_annual_kwh_savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        estimated_annual_mmbtu_savings  first_year_energy_savings_$_estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#        homeowner_received_free/reduced_cost_audit?  \
# 0                                             True
# 1                                             True
# 2                                             True
# 3                                             True
# 4                                             True
# ...                                            ...
# 55825                                        False
# 55826                                        False
# 55827                                        False
# 55828                                        False
# 55829                                        False
#
#                                                 location  new_york_zip_codes  \
# 0      {'type': 'Point', 'coordinates': [-75.16936, 4...               764.0
# 1      {'type': 'Point', 'coordinates': [-77.218837, ...               364.0
# 2      {'type': 'Point', 'coordinates': [-78.808435, ...                71.0
# 3      {'type': 'Point', 'coordinates': [-75.454665, ...              1366.0
# 4      {'type': 'Point', 'coordinates': [-77.603561, ...               312.0
# ...                                                  ...                 ...
# 55825  {'type': 'Point', 'coordinates': [-78.702553, ...               506.0
# 55826  {'type': 'Point', 'coordinates': [-73.932117, ...                72.0
# 55827  {'type': 'Point', 'coordinates': [-76.359264, ...               622.0
# 55828  {'type': 'Point', 'coordinates': [-77.597999, ...              1676.0
# 55829  {'type': 'Point', 'coordinates': [-77.729647, ...              1683.0
#
#        counties_2  nys_municipal_boundaries_2
# 0           625.0                         985
# 1           631.0                         631
# 2          2041.0                         300
# 3           625.0                         989
# 4          2091.0                         742
# ...           ...                         ...
# 55825      2041.0                         298
# 55826      2030.0                         832
# 55827      2181.0                         712
# 55828      2093.0                         545
# 55829      2093.0                         549
#
# [55830 rows x 29 columns]

# %% [markdown]
# ## Column 25: New Georeferenced Column

# %%
import ast

df["latitude"] = df["location"].apply(lambda x: ast.literal_eval(x)["coordinates"][0])
df["longitude"] = df["location"].apply(lambda x: ast.literal_eval(x)["coordinates"][1])
df.drop(["location"], axis=1, inplace=True)

# %% [markdown]
# ## Columns 26 - 28: Remove columns

# %%
df.drop(["new_york_zip_codes", "counties_2", "nys_municipal_boundaries_2"], axis=1, inplace=True)

# %% [markdown]
# ## Final dataframe

# %%
df
# Out:
#               reporting_period home_performance_project_id  \
# 0      2020-02-12T00:00:00.000                      483911
# 1      2020-02-12T00:00:00.000                      486389
# 2      2020-02-12T00:00:00.000                      483374
# 3      2020-02-12T00:00:00.000                      475733
# 4      2020-02-12T00:00:00.000                      483731
# ...                        ...                         ...
# 55825  2020-02-12T00:00:00.000                P00000721450
# 55826  2020-02-12T00:00:00.000                P00000727276
# 55827  2020-02-12T00:00:00.000                P00000726343
# 55828  2020-02-12T00:00:00.000                P00000727199
# 55829  2020-02-12T00:00:00.000                P00000725072
#
#       home_performance_site_id project_county project_city  project_zip  \
# 0                       357221         Oneida    Barneveld        13304
# 1                       343438          Wayne      Palmyra        14522
# 2                       356880           Erie      Buffalo        14215
# 3                       350454         Oneida         Rome        13440
# 4                       356491     Livingston         Lima        14485
# ...                        ...            ...          ...          ...
# 55825             S00000124921           Erie        Depew        14043
# 55826             S00000130155    Schenectady  Schenectady        12303
# 55827             S00000129326       Tompkins    Freeville        13068
# 55828             S00000130090         Monroe    Rochester        14617
# 55829             S00000128120         Monroe    Rochester        14624
#
#                  gas_utility_provider      electric_utility_provider  \
# 0                                 NaN                  National Grid
# 1                                 NaN  New York State Electric & Gas
# 2      National Fuel Gas Distribution                  National Grid
# 3                                 NaN                  National Grid
# 4                                 NaN                  National Grid
# ...                               ...                            ...
# 55825  National Fuel Gas Distribution  New York State Electric & Gas
# 55826                   National Grid                  National Grid
# 55827   New York State Electric & Gas  New York State Electric & Gas
# 55828        Rochester Gas & Electric       Rochester Gas & Electric
# 55829        Rochester Gas & Electric       Rochester Gas & Electric
#
#        project_completion_date customer_type          job_type  \
# 0      2021-01-16T00:00:00.000      Assisted  Home Performance
# 1      2021-01-06T00:00:00.000      Assisted  Home Performance
# 2      2020-12-15T00:00:00.000      Assisted  Home Performance
# 3      2020-12-09T00:00:00.000      Assisted  Home Performance
# 4      2020-12-08T00:00:00.000      Assisted  Home Performance
# ...                        ...           ...               ...
# 55825  2010-11-15T00:00:00.000        Market  Home Performance
# 55826  2011-01-28T00:00:00.000      Assisted  Home Performance
# 55827  2011-01-13T00:00:00.000        Market  Home Performance
# 55828  2010-12-26T00:00:00.000        Market  Home Performance
# 55829  2011-02-01T00:00:00.000        Market  Home Performance
#
#        total_project_cost  total_incentives type_of_program_financing  \
# 0                    5900              2950                       NaN
# 1                    9980              3250                       NaN
# 2                    5000              2500                       NaN
# 3                    4200              2088                       NaN
# 4                    5890              2945                       NaN
# ...                   ...               ...                       ...
# 55825                4000               400                       NaN
# 55826                9802              4901                       NaN
# 55827                6034                 0                    ESMART
# 55828                8454               845                       NaN
# 55829               12488              1249                       NaN
#
#        amount_financed_through_program pre-retrofit_home_heating_fuel_type  \
# 0                                    0                                 NaN
# 1                                    0                             Propane
# 2                                    0                         Natural Gas
# 3                                    0                                 NaN
# 4                                    0                             Propane
# ...                                ...                                 ...
# 55825                                0                         Natural Gas
# 55826                                0                                 Oil
# 55827                                0                                 Oil
# 55828                                0                         Natural Gas
# 55829                                0                         Natural Gas
#
#        year_home_built  size_of_home  volume_of_home  number_of_units  \
# 0               1947.0      222.7742       543.29088              1.0
# 1               1966.0      101.4468       241.20144              1.0
# 2               1928.0      150.1264       581.01312              1.0
# 3               1971.0       91.0420       222.02880              1.0
# 4               1984.0       87.3260       212.96640              1.0
# ...                ...           ...             ...              ...
# 55825           1965.0      166.1052       405.08928              1.0
# 55826           1949.0      275.2627       671.29728              1.0
# 55827           1968.0      100.3320       244.68480              1.0
# 55828           1965.0      303.9688       718.90320              1.0
# 55829           1959.0      217.3860       530.15040              1.0
#
#          measure_type  estimated_annual_kwh_savings  \
# 0      Building Shell                             0
# 1      Building Shell                           309
# 2      Building Shell                             0
# 3      Building Shell                             0
# 4      Building Shell                             0
# ...               ...                           ...
# 55825  Building Shell                             0
# 55826  Building Shell                             0
# 55827  Building Shell                             0
# 55828  Building Shell                           601
# 55829  Building Shell                             0
#
#        estimated_annual_mmbtu_savings  first_year_energy_savings_$_estimate  \
# 0                                  27                                   474
# 1                                   3                                   111
# 2                                   8                                    61
# 3                                  28                                   681
# 4                                   6                                   146
# ...                               ...                                   ...
# 55825                              24                                   340
# 55826                              33                                   823
# 55827                              16                                   887
# 55828                              11                                   258
# 55829                               1                                     9
#
#        homeowner_received_free/reduced_cost_audit?   latitude  longitude
# 0                                             True -75.169360  43.241398
# 1                                             True -77.218837  43.059660
# 2                                             True -78.808435  42.934202
# 3                                             True -75.454665  43.214717
# 4                                             True -77.603561  42.886564
# ...                                            ...        ...        ...
# 55825                                        False -78.702553  42.904567
# 55826                                        False -73.932117  42.759175
# 55827                                        False -76.359264  42.505028
# 55828                                        False -77.597999  43.221623
# 55829                                        False -77.729647  43.128513
#
# [55830 rows x 27 columns]
